# %%
# Support Vector Machine (SVM)

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# Importing the dataset
dataset = pd.read_csv("update7.csv")
dataset =dataset.replace([np.inf, -np.inf], np.nan)
dataset=dataset.dropna()
dataset.columns=['ira','irb','irc','ird','ci','ai','col','edge','mean','std','label','name']

X = dataset[['ira','irb','irc','ird','ci','ai','col','edge','mean','std']].values
#'ai', 'ci', 'std', 'irb', 'ira', 'col', 'mean', 'irc', 'colvar'
#'ai', 'ci', 'std', 'edge', 'irb', 'ira', 'col', 'mean', 'irc'
y = dataset['label'].values



# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0,shuffle=True)


#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state =0)
classifier.fit(X_train, y_train)


y_pred=classifier.predict(X_test)

from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7516930022573364

# %%
dataset
# Out:
#            ira       irb       irc         ird        ci        ai  col  \
# 0     0.017561  3.535974  2.491174  190.741180  0.438542  0.122329    3
# 1     0.025185  4.987564  2.796229  160.481630  0.223943  0.243822    1
# 2     0.013661  3.090491  3.414616  329.705720  0.473869  0.086903    3
# 3     0.016668  3.828649  1.237170  108.643650  0.442654  0.212715    2
# 4     0.015177  3.391087  2.449618  213.089690  0.480557  0.112513    2
# ...        ...       ...       ...         ...       ...       ...  ...
# 2207  0.018336  3.556938  0.743756   53.281723  0.625389  0.097512    2
# 2208  0.011279  4.460854  0.480253   54.834350  0.442724  0.076281    3
# 2209  0.016355  4.947753  1.241271   99.550080  0.312866  0.148372    2
# 2210  0.019124  3.593563  3.074964  219.439000  0.384251  0.167293    4
# 2211  0.017508  3.037290  1.571407  116.866270  0.689444  0.051828    3
#
#           edge        mean        std  label              name
# ...

# %%
dataset.describe()
# Out:
#                ira          irb          irc          ird           ci  \
# count  2212.000000  2212.000000  2212.000000  2212.000000  2212.000000
# mean      0.021679     3.976202     1.972980   134.584037     0.448286
# std       0.008067     1.032171     1.463288    90.809758     0.172739
# min       0.008026     2.264831     0.032736     3.676941     0.055074
# 25%       0.015924     3.325643     1.028488    70.176696     0.325061
# 50%       0.020052     3.687893     1.674097   117.236000     0.464238
# 75%       0.025280     4.306307     2.497244   175.697685     0.584253
# max       0.072490    11.543640    13.577836   655.093400     0.840386
#
#                 ai          col         edge         mean          std  \
# count  2212.000000  2212.000000  2212.000000  2212.000000  2212.000000
# mean      0.145080     2.219711     0.045496   106.499905    19.440742
# std       0.102328     0.802873     0.048863    24.800538     5.840580
# ...

# %%
dataset.label.value_counts()
# Out:
# 1    1113
# 0    1099
# Name: label, dtype: int64

# %%
#'ira','irb','irc','ird','ci','ai','col','edge','mean','std'
classifier.coef_
# Out:
# array([[-3.58326452e-02,  2.78801975e-01, -1.34581583e-01,
#          2.95291939e-03, -1.78501516e+00,  6.23128637e+00,
#         -3.82788048e-01,  1.56476720e+00, -1.68759429e-02,
#          1.42887996e-01]])

# %%
classifier.intercept_
# Out:
# array([-1.48299157])

# %%
# Support Vector Machine (SVM)

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# Importing the dataset
dataset = pd.read_csv('update7.csv')
dataset =dataset.replace([np.inf, -np.inf], np.nan)
dataset=dataset.dropna()
dataset.columns=['ira','irb','irc','ird','ci','ai','col','edge','mean','std','label','name']

X1= dataset[['ira','irb','irc','ird','ci','ai','col','edge','mean','std','label','name']].values
X = dataset[['ira','irb','irc','ird','ci','ai','col','edge','mean','std']].values



y = dataset['label'].values



# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size = 0.2, random_state = 0)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
for i in range(0,len(X_train)):
    print(X_train[i][11],X_train[i][10],y_train[i])
# Out:
# ISIC_0024738.jpg 0 0
# ISIC_0025701.jpg 0 0
# ISIC_0025511.jpg 0 0
# ISIC_0025169.jpg 0 0
# ISIC_0024493.jpg 0 0
# ISIC_0025329.jpg 0 0
# ISIC_0025482.jpg 0 0
# ISIC_0025889.jpg 0 0
# ISIC_0032425.jpg 1 1
# ISIC_0026652.jpg 1 1
# ISIC_0033287.jpg 1 1
# ISIC_0025745.jpg 0 0
# ISIC_0025371.jpg 0 0
# ISIC_0025163.jpg 0 0
# ISIC_0024624.jpg 1 1
# ISIC_0024911.jpg 1 1
# ISIC_0033017.jpg 1 1
# ISIC_0030929.jpg 1 1
# ISIC_0024728.jpg 0 0
# ISIC_0033074.jpg 1 1
# ISIC_0025779.jpg 0 0
# ISIC_0034289.jpg 1 1
# ISIC_0025007.jpg 0 0
# ISIC_0024780.jpg 0 0
# ISIC_0025092.jpg 0 0
# ISIC_0024597.jpg 0 0
# ISIC_0025931.jpg 0 0
# ISIC_0024506.jpg 0 0
# ISIC_0026868.jpg 1 1
# ISIC_0025751.jpg 1 1
# ISIC_0025528.jpg 0 0
# ISIC_0024930.jpg 1 1
# ISIC_0025415.jpg 0 0
# ISIC_0025887.jpg 0 0
# ISIC_0032269.jpg 1 1
# ISIC_0024924.jpg 0 0
# ISIC_0025070.jpg 0 0
# ISIC_0028548.jpg 1 1
# ISIC_0030925.jpg 1 1
# ISIC_0028126.jpg 1 1
# ISIC_0029265.jpg 1 1
# ISIC_0025410.jpg 0 0
# ISIC_0028361.jpg 1 1
# ...

# %%
for i in range(0,len(X_test)):
    
    ans=np.dot(X_test1[i],classifier.coef_[0].T)+classifier.intercept_
    print('{}\t{}\t{}\t{}'.format(X_test[i][11],y_test[i],y_pred[i],ans))
# Out:
# ISIC_0025267.jpg	0	0	[-0.34030001]
# ISIC_0025505.jpg	0	0	[-0.74527534]
# ISIC_0029502.jpg	1	1	[0.00754437]
# ISIC_0024916.jpg	0	0	[-1.47691605]
# ISIC_0029212.jpg	1	1	[1.82929902]
# ISIC_0025253.jpg	0	0	[-0.4302969]
# ISIC_0026954.jpg	1	1	[1.67757858]
# ISIC_0025037.jpg	0	0	[-1.86417564]
# ISIC_0025173.jpg	0	0	[-1.56248917]
# ISIC_0024536.jpg	0	0	[-0.07524426]
# ISIC_0026989.jpg	1	0	[-0.13464858]
# ISIC_0032476.jpg	1	1	[3.15728943]
# ISIC_0024388.jpg	0	1	[0.65837253]
# ISIC_0025918.jpg	0	1	[0.23202937]
# ISIC_0026500.jpg	1	1	[0.54944743]
# ISIC_0025555.jpg	0	1	[0.01730523]
# ISIC_0025243.jpg	0	1	[0.05007011]
# ISIC_0025480.jpg	0	0	[-2.11286457]
# ISIC_0025603.jpg	1	0	[-0.113245]
# ISIC_0024521.jpg	0	0	[-0.9146766]
# ISIC_0028352.jpg	1	1	[1.55660127]
# ISIC_0025778.jpg	0	0	[-0.15527431]
# ISIC_0025220.jpg	0	0	[-1.73185452]
# ISIC_0029172.jpg	1	1	[0.87558995]
# ISIC_0033238.jpg	1	1	[1.78149284]
# ISIC_0033953.jpg	1	0	[-0.0190545]
# ISIC_0024365.jpg	0	0	[-0.60602811]
# ...

# %%
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    import numpy as np
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import confusion_matrix
   

    ypred1=y_pred
    accuracy=accuracy_score(y_test, ypred1)
    precision= precision_score(y_test,ypred1)
    recall= recall_score(y_test,ypred1)
    tn, fp, fn, tp = confusion_matrix(y_test, ypred1).ravel()
    specificity01 = tn / (tn+fp)
    f1= f1_score(y_test,ypred1) 
    auc = roc_auc_score(y_test, ypred1)
    print(accuracy,precision,recall,specificity01,f1,auc)
# Out:
# 0.7516930022573364 0.7623762376237624 0.7129629629629629 0.788546255506608 0.7368421052631577 0.7507546092347853

# %%
from sklearn.linear_model import LogisticRegression
import csv
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
ss=SVC(kernel = 'linear', random_state =1234)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_curve, roc_auc_score
import tensorflow as tf

# Instantiate the classfiers and make a list
classifiers = [ss,

               ]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    if cls==ss:
      model = cls.fit(X_train, y_train)
      ypred=cls.predict(X_test)
      fpr, tpr, _ =roc_curve(y_test,  ypred)
      auc = roc_auc_score(y_test, ypred)



      


      
      
    else:
      model = cls.fit(X_train, y_train)
      yproba = model.predict(X_test)
    
      fpr, tpr, _ = roc_curve(y_test,  yproba)
      auc = roc_auc_score(y_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)
    #append_to_csv([cls.__class__.__name__,fpr,tpr,auc],'allmodelreal.csv')
# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-76de7bff3bb0> in <module>
#      24 for cls in classifiers:
#      25     if cls==ss:
# ---> 26       model = cls.fit(X_train, y_train)
#      27       ypred=cls.predict(X_test)
#      28       fpr, tpr, _ =roc_curve(y_test,  ypred)
#
# c:\users\hp\anaconda3\envs\venvs\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     167             check_consistent_length(X, y)
#     168         else:
# --> 169             X, y = self._validate_data(X, y, dtype=np.float64,
#     170                                        order='C', accept_sparse='csr',
#     171                                        accept_large_sparse=False)
#
# c:\users\hp\anaconda3\envs\venvs\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize=(10,8))
colors=['purple','blue','skyblue','red','green']
count=0
for i in result_table.index:
    jj=i
    count+=1
    if i=='Sequential':
      jj='CNN+BiLSTM'
    elif i=='SVC':
      jj='SVM'
    else:
      jj=i

    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             
               
             label="{}, AUC={:.2f}".format(jj, result_table.loc[i]['auc']),color=colors[count-1],alpha=10)
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')
legend_properties = {'weight':'bold'}



plt.xticks(np.arange(0.0, 1.1, step=0.1),fontweight='bold',fontsize=20)
plt.xlabel("Flase Positive Rate", fontsize=25,fontweight='bold')

plt.yticks(np.arange(0.0, 1.1, step=0.1),fontweight='bold',fontsize=20)
plt.ylabel("True Positive Rate", fontsize=25,fontweight='bold')

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=20)
plt.legend(prop={'size':20,'weight':'bold'}, loc='lower right')

plt.show()

# %%
#90% Training

# %%
# Support Vector Machine (SVM)

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# Importing the dataset
dataset = pd.read_csv("update7.csv")
dataset =dataset.replace([np.inf, -np.inf], np.nan)
dataset=dataset.dropna()
dataset.columns=['ira','irb','irc','ird','ci','ai','col','edge','mean','std','label','name']

X = dataset[['ira','irb','irc','ird','ci','ai','col','edge','mean','std']].values
#'ai', 'ci', 'std', 'irb', 'ira', 'col', 'mean', 'irc', 'colvar'
#'ai', 'ci', 'std', 'edge', 'irb', 'ira', 'col', 'mean', 'irc'
y = dataset['label'].values



# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0,shuffle=True)


#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state =0)
classifier.fit(X_train, y_train)


y_pred=classifier.predict(X_test)

from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7792792792792793

# %%
    from sklearn.metrics import recall_score
    from sklearn.metrics import f1_score
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import precision_score
    import numpy as np
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import confusion_matrix


    ypred1=y_pred
    accuracy=accuracy_score(y_test, ypred1)
    precision= precision_score(y_test,ypred1)
    recall= recall_score(y_test,ypred1)
    tn, fp, fn, tp = confusion_matrix(y_test, ypred1).ravel()
    specificity01 = tn / (tn+fp)
    f1= f1_score(y_test,ypred1)
    auc = roc_auc_score(y_test, ypred1)
    print(accuracy,precision,recall,specificity01,f1,auc)
# Out:
# 0.7792792792792793 0.7708333333333334 0.7326732673267327 0.8181818181818182 0.751269035532995 0.7754275427542754

# %%
from sklearn.linear_model import LogisticRegression
import csv
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
ss=SVC(kernel = 'linear', random_state =1234)
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

from sklearn.metrics import roc_curve, roc_auc_score
import tensorflow as tf

# Instantiate the classfiers and make a list
classifiers = [ss,

               ]

# Define a result table as a DataFrame
result_table = pd.DataFrame(columns=['classifiers', 'fpr','tpr','auc'])

# Train the models and record the results
for cls in classifiers:
    if cls==ss:
      model = cls.fit(X_train, y_train)
      ypred=cls.predict(X_test)
      fpr, tpr, _ =roc_curve(y_test,  ypred)
      auc = roc_auc_score(y_test, ypred)



      


      
      
    else:
      model = cls.fit(X_train, y_train)
      yproba = model.predict(X_test)
    
      fpr, tpr, _ = roc_curve(y_test,  yproba)
      auc = roc_auc_score(y_test, yproba)
    
    result_table = result_table.append({'classifiers':cls.__class__.__name__,
                                        'fpr':fpr, 
                                        'tpr':tpr, 
                                        'auc':auc}, ignore_index=True)
    #append_to_csv([cls.__class__.__name__,fpr,tpr,auc],'allmodelreal.csv')
# Set name of the classifiers as index labels
result_table.set_index('classifiers', inplace=True)

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
fig = plt.figure(figsize=(10,8))
colors=['purple','blue','skyblue','red','green']
count=0
for i in result_table.index:
    jj=i
    count+=1
    if i=='Sequential':
      jj='CNN+BiLSTM'
    elif i=='SVC':
      jj='SVM'
    else:
      jj=i

    plt.plot(result_table.loc[i]['fpr'], 
             result_table.loc[i]['tpr'], 
             
               
             label="{}, AUC={:.2f}".format(jj, result_table.loc[i]['auc']),color=colors[count-1],alpha=10)
    
plt.plot([0,1], [0,1], color='orange', linestyle='--')
legend_properties = {'weight':'bold'}



plt.xticks(np.arange(0.0, 1.1, step=0.1),fontweight='bold',fontsize=20)
plt.xlabel("Flase Positive Rate", fontsize=25,fontweight='bold')

plt.yticks(np.arange(0.0, 1.1, step=0.1),fontweight='bold',fontsize=20)
plt.ylabel("True Positive Rate", fontsize=25,fontweight='bold')

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=20)
plt.legend(prop={'size':20,'weight':'bold'}, loc='lower right')

plt.show()
